# %% [markdown]
# # Chapter 7 Tutorial: Building Your Own Retrieval-Augmented Generation System
#
# Retrieval-augmented generation is a promising avenue for combining the semantic understanding capabilities of LLMs with the factual accuracy of direct source materials. In Chapter 7, we discussed many aspects of these systems, from basic approaches to optimization to enhancements to the core RAG functionality and methods for evaluating RAG performance. This section will present a practical, hands-on example of building and augmenting a RAG system using a popular open-source RAG application. This tutorial is far from an exhaustive exploration of RAG capabilities, but aims to overview a few critical techinques while introducing the use of LlamaIndex.
#
# Requirements:
#
# 1.   An OpenAI account with an API key.

# %% [markdown]
# ## Installation and Imports

# %%
# %pip install -U -q llama-index-core \
                   llama-index-finetuning \
                   llama-index-embeddings-openai \
                   llama-index-embeddings-huggingface \
                   llama-index-llms-openai \
                   llama-index-embeddings-adapter \
                   llama-index-postprocessor-cohere-rerank \
                   llama-index-llms-gradient

# %pip install openai==1.12.0 -q -U
# %pip install sentence_transformers -q -U
# %pip install datasets -q -U
# %pip install accelerate -q -U
# Out:
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import torch
import nest_asyncio
import getpass
#from google.colab import drive
import locale
locale.getpreferredencoding = lambda: "UTF-8"

from tqdm import tqdm
import pandas as pd

# Turn on async
nest_asyncio.apply()

# Enter OpenAI API key
#os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter Your OpenAI API Key: ")
os.environ["OPENAI_API_KEY"] = 'key'

# %%
from tqdm import tqdm
import pandas as pd
import torch

from llama_index.core import (
    Document,
    VectorStoreIndex,
    StorageContext,
    load_index_from_storage,
    PromptTemplate,
    get_response_synthesizer
)

from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.openai import OpenAI

from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import LLMRerank
from llama_index.core.response_synthesizers import ResponseMode

from llama_index.core.evaluation import (
    EmbeddingQAFinetuneDataset,
    FaithfulnessEvaluator,
    RelevancyEvaluator,
    RetrieverEvaluator
)

from llama_index.finetuning import generate_qa_embedding_pairs, SentenceTransformersFinetuneEngine
from sklearn.model_selection import train_test_split

from sentence_transformers.evaluation import InformationRetrievalEvaluator
from sentence_transformers import SentenceTransformer
from pathlib import Path

# %% [markdown]
# ## Basic RAG system

# %% [markdown]
# **NOTE**: Before continuing, copy openai_tos.zip from the chapter 7 tutorial repository into your working directory.

# %%
## Unzip the openai TOS.
#!unzip ./openai_tos.zip
directory = './openai_tos/'
doc_names = sorted(os.listdir(directory))

## Collect each TOS doc into a llama_index Document object
documents = []
for i, doc_name in enumerate(doc_names):
  document = open(directory+doc_name).read()
  d = Document(
      text=document,
      metadata = {"file": doc_name, "name": doc_name.split('_')[1].split('.')[0].replace('-',' ')}
  )
  documents.append(d)

# %%
documents
# Out:
# [Document(id_='8e2acab2-41b3-464f-abb6-fc5376a96742', embedding=None, metadata={'file': '01_terms-of-use.txt', 'name': 'terms of use'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Terms of use\nUpdated\nNovember 14, 2023\nEffective: January 31, 2024 (previous version)\n\nThank you for using OpenAI!\n\nThese Terms of Use apply to your use of ChatGPT, DALL·E, and OpenAI’s other services for individuals, along with any associated software applications and websites (all together, “Services”). These Terms form an agreement between you and OpenAI, L.L.C., a Delaware company, and they include our Service Terms and important provisions for resolving disputes through arbitration. By using our Services, you agree to these Terms. \n\nIf you reside in the European Economic Area, Switzerland, or the UK, your use of the Services is governed by these terms.\n\nOur Business Terms govern use of ChatGPT Enterprise, our APIs, and our other services for businesses and developers. \n\nOur Privacy Policy explains how we collect and use personal information. Although it does not form part of these Terms, it is an important document that you should read.\n\nWho we are\nOpenAI is an AI research and deployment company. Our mission is to ensure that artificial general intelligence benefits all of humanity. For more information about OpenAI, please visit https://openai.com/about.\n\nRegistration and Access\nMinimum Age. You must be at least 13 years old or the minimum age required in your country to consent to use the Services. If you are under 18 you must have your parent or legal guardian’s permission to use the Services. \n\nRegistration. You must provide accurate and complete information to register for an account to use our Services. You may not share your account credentials or make your account available to anyone else and are responsible for all activities that occur under your account. If you create an account or use the Services on behalf of another person or entity, you must have the authority to accept these Terms on their behalf.\n\nUsing Our Services\nWhat You Can Do. Subject to your compliance with these Terms, you may access and use our Services. In using our Services, you must comply with all applicable laws as well as our Sharing & Publication Policy, Usage Policies, and any other documentation, guidelines, or policies we make available to you. \n\nWhat You Cannot Do. You may not use our Services for any illegal, harmful, or abusive activity. For example, you may not:\n\nUse our Services in a way that infringes, misappropriates or violates anyone’s rights.\nModify, copy, lease, sell or distribute any of our Services.\nAttempt to or assist anyone to reverse engineer, decompile or discover the source code or underlying components of our Services, including our models, algorithms, or systems (except to the extent this restriction is prohibited by applicable law).\nAutomatically or programmatically extract data or Output (defined below).\nRepresent that Output was human-generated when it was not.\nInterfere with or disrupt our Services, including circumvent any rate limits or restrictions or bypass any protective measures or safety mitigations we put on our Services.\nUse Output to develop models that compete with OpenAI.\nSoftware. Our Services may allow you to download software, such as mobile applications, which may update automatically to ensure you’re using the latest version. Our software may include open source software that is governed by its own licenses that we’ve made available to you.\n\nCorporate Domains. If you create an account using an email address owned by an organization (for example, your employer), that account may be added to the organization's business account with us, in which case we will provide notice to you so that you can help facilitate the transfer of your account (unless your organization has already provided notice to you that it may monitor and control your accoun ...
#  Document(id_='ac7e3cf4-bd54-4d44-ae8d-db68be815742', embedding=None, metadata={'file': '02_privacy-policy.txt', 'name': 'privacy policy'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Privacy policy\nUpdated\nNovember 14, 2023\nEffective: January 31, 2024\n\nWe’ve updated our Privacy Policy below. These updates do not apply to individuals located in the European Economic Area, UK, and Switzerland. If you reside in those areas, this version of our Privacy Policy applies to you.\n\nWe at OpenAI OpCo, LLC (together with our affiliates, “OpenAI”, “we”, “our” or “us”) respect your privacy and are strongly committed to keeping secure any information we obtain from you or about you. This Privacy Policy describes our practices with respect to Personal Information we collect from or about you when you use our website, applications, and services (collectively, “Services”). This Privacy Policy does not apply to content that we process on behalf of customers of our business offerings, such as our API. Our use of that data is governed by our customer agreements covering access to and use of those offerings.\n\nFor information about how we collect and use training information to develop our language models that power ChatGPT and other Services, and your choices with respect to that information, please see this help center article.\n\n1. Personal information we collect\nWe collect personal information relating to you (“Personal Information”) as follows:\n\nPersonal Information You Provide: We collect Personal Information if you create an account to use our Services or communicate with us as follows:\n\nAccount Information: When you create an account with us, we will collect information associated with your account, including your name, contact information, account credentials, payment card information, and transaction history, (collectively, “Account Information”).\nUser Content: When you use our Services, we collect Personal Information that is included in the input, file uploads, or feedback that you provide to our Services (“Content”). \nCommunication Information: If you communicate with us, we collect your name, contact information, and the contents of any messages you send (“Communication Information”).\nSocial Media Information: We have pages on social media sites like Instagram, Facebook, Medium, Twitter, YouTube and LinkedIn. When you interact with our social media pages, we will collect Personal Information that you elect to provide to us, such as your contact details (collectively, “Social Information”). In addition, the companies that host our social media pages may provide us with aggregate information and analytics about our social media activity.\nOther Information You Provide: We collect other information that you may provide to us, such as when you participate in our events or surveys or provide us with information to establish your identity (collectively, “Other Information You Provide”\nPersonal Information We Receive Automatically From Your Use of the Services: When you visit, use, or interact with the Services, we receive the following information about your visit, use, or interactions (“Technical Information”):\n\nLog Data: Information that your browser or device automatically sends when you use our Services. Log data includes your Internet Protocol address, browser type and settings, the date and time of your request, and how you interact with our Services.\nUsage Data: We may automatically collect information about your use of the Services, such as the types of content that you view or engage with, the features you use and the actions you take, as well as your time zone, country, the dates and times of access, user agent and version, type of computer or mobile device, and your computer connection.\nDevice Information: Includes name of the device, operating system, device identifiers, and browser you are using. Information collected may depend on the type of device you use and ...
#  Document(id_='27d6a307-e947-47ba-97a1-39025f68fd4f', embedding=None, metadata={'file': '03_service-terms.txt', 'name': 'service terms'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Service terms\nUpdated\nJanuary 10, 2024\nThese Service Terms govern your use of the Services. Capitalized terms not defined here will have the meanings in the Terms of Use, Business Terms, or other agreement you have with us governing your use of the Services (“Agreement”). If there is a conflict between the Service Terms and your Agreement, the Service Terms will control. For purposes of these Terms, “Content” includes “Customer Content.”\n\n1. API\nOpenAI’s indemnification obligations to API customers under the Agreement include any third party claim that Customer’s use or distribution of Output infringes a third party’s intellectual property right. This indemnity does not apply where: (i) Customer or Customer’s End Users knew or should have known the Output was infringing or likely to infringe, (ii) Customer or Customer’s End Users disabled, ignored, or did not use any relevant citation, filtering or safety features or restrictions provided by OpenAI, (iii) Output was modified, transformed, or used in combination with products or services not provided by or on behalf of OpenAI, (iv) Customer or its End Users did not have the right to use the Input or fine-tuning files to generate the allegedly infringing Output, (v) the claim alleges violation of trademark or related rights based on Customer’s or its End Users’ use of Output in trade or commerce, and (vi) the allegedly infringing Output is from content from a Third Party Offering.\n\n2. Beta Services\nThis section governs your use of services or features that OpenAI offers on an alpha, preview, early access, or beta basis (“Beta Services”). Beta Services are offered “as-is” to allow testing and evaluation and are excluded from any indemnification obligations OpenAI may have to you.\n\nOpenAI makes no representations or warranties for Beta Services, including any warranty that Beta Services will be generally available, uninterrupted or error-free, or that Content will be secure or not lost or damaged. Except to the extent prohibited by law, OpenAI expressly disclaims all warranties for Beta Services, including any implied warranties of merchantability, satisfactory quality, fitness for a particular purpose, non-infringement, or quiet enjoyment, and any warranties arising out of any course of dealing or usage of trade.\n\n3. ChatGPT Enterprise and Team\n(a) Administrators. ChatGPT Enterprise and Team accounts are managed by End Users with administrative privileges (“Administrators”). Administrators may be able to add, remove and suspend End Users’ access to the organization’s workspace. In addition, ChatGPT Enterprise Administrators may be able to (a) access, share and remove Content; and (b) access logging and information about End Users’ use of ChatGPT Enterprise. Customers are responsible for obtaining and maintaining all necessary consents from End Users to take the actions above and to allow OpenAI to deliver the Services.\n\n(b) Output indemnity. OpenAI’s indemnification obligations to ChatGPT Enterprise customers under the Agreement include claims that Customer’s use or distribution of Output infringes a third party’s intellectual property right. This indemnity does not apply where: (i) Customer or Customer’s End Users knew or should have known the Output was infringing or likely to infringe, (ii) Customer or Customer’s End Users disabled, ignored, or did not use any relevant citation, filtering or safety features or restrictions provided by OpenAI, (iii) Output was modified, transformed, or used in combination with products or services not provided by or on behalf of OpenAI, (iv) Customer or its End Users did not have the right to use the Input or fine-tuning files to generate the allegedly infringing Output, (v) the claim alleges violation of t ...
#  Document(id_='7c60198f-7f05-4054-b4ad-137917132703', embedding=None, metadata={'file': '04_data-processing-addendum.txt', 'name': 'data processing addendum'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Data processing addendum\nExecute OpenAI's Data Protection Agreement here. We have provided the complete terms of the agreement below for your convenience.\n\nUpdated\nJanuary 12, 2024\nThis Data Processing Addendum (“DPA”) governs OpenAI’s processing of Customer Data (as defined below) provided by Customer to OpenAI through OpenAI’s API, ChatGPT Enterprise, ChatGPT Team, or any OpenAI services for businesses or developers (the “Services”) under the terms of the OpenAI Business Terms (located at openai.com/policies/business-terms), Enterprise Agreement, or other agreement between Customer and OpenAI governing Customer’s use of the Services (the “Agreement”) and is hereby incorporated into the Agreement. If and to the extent language in this DPA conflicts with the Agreement, the conflicting terms in this DPA shall control. Capitalized terms not defined in this DPA have the meaning set forth in the Agreement. For purposes of this DPA only, “Customer” includes any affiliate entity of Customer’s that (a) has entered into an Order Form with OpenAI and that (b) directly or indirectly, through one or more intermediaries, controls, is controlled by, or is under common control with Customer.\n\nOpenAI and Customer each agree to comply with their respective obligations under applicable data privacy and data protection laws (collectively, “Data Protection Laws”) in connection with the Services. Data Protection Laws may include, depending on the circumstances, Cal. Civ. Code §§ 1798.100 et seq., as amended by the California Privacy Rights Act of 2020 (the California Consumer Privacy Act) (“CCPA”), Colo. Rev. Stat. §§ 6-1-1301 et seq. (the Colorado Privacy Act) (“CPA”), Connecticut’s Data Privacy Act (“CTDPA”), Utah Code Ann. §§ 13-61-101 et seq. (the Utah Consumer Privacy Act) (“UCPA”), VA Code Ann. §§ 59.1-575 et seq. (the Virginia Consumer Data Protection Act) (“VCDPA”) (collectively “U.S. Privacy Laws”), and the United Kingdom and/orEuropean Union General Data Protection Regulation (Regulation (EU) 2016/679) (collectively the “GDPR”), and applicable subordinate legislation and regulations implementing those laws.\n\nIn connection with the Agreement, Customer is the person that determines the purposes and means for which Customer Data (as defined below) is processed (a “Data Controller”), whereas OpenAI processes Customer Data in accordance with the Data Controller’s instructions and on behalf of the Data Controller (as a “Data Processor”). “Data Controller” and “Data Processor” also mean the equivalent concepts under Data Protection Laws. For purposes of the Agreement and this DPA, (i) “Personal Data” has the meaning assigned to the term “personal data” or “personal information” under applicable Data Protection Laws; and (ii)“Customer Data” means Personal Data that Customer provides to OpenAI that OpenAI processes on behalf of Customer to provide the Services. OpenAI will process Customer Data as Customer’s Data Processor to provide or maintain the Services and for the purposes set forth in this DPA, the Agreement and/or in any other applicable agreements between Customer and OpenAI.\n\n1. Processing Requirements\nAs a Data Processor, OpenAI agrees to:\n\na. process Customer Data only (i) on Customer’s behalf for the purpose of providing and supporting OpenAI’s Services (including to provide insights, reporting, analytics and platform abuse, trust and safety monitoring); (ii) in compliance with the written instructions received from Customer; and (iii) in a manner that provides no less than the level of privacy protection required of it by Data Protection Laws;\n\nb. promptly inform Customer in writing if OpenAI cannot comply with the requirements of this DPA;\n\nc. not provide Customer with  ...
#  Document(id_='06a61585-a773-4f90-a8f0-a5d59acf7d8b', embedding=None, metadata={'file': '05_plugins-and-actions-terms.txt', 'name': 'plugins and actions terms'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Plugins and Actions Terms\nUpdated\nJanuary 10, 2024\n1. Introduction\nPlugins and Actions (together “Plugins”) allow OpenAI services (“Services”) such as ChatGPT to retrieve information from or send instructions to an API (“API”) created according to our AI Plugin Protocol. Users of OpenAI Services can choose to enable Plugins within certain Services. For example, a ChatGPT user who wants to make a restaurant reservation could enable a restaurant reservation Plugin and instruct ChatGPT to make the reservation.\n\nThese Plugin Terms (“Terms”) govern the creation and use of your Plugin in connection with OpenAI Services. If you reside within the European Economic Area or Switzerland your agreement is with OpenAI Ireland Ltd. These Terms include our Usage Policies and other documentation, guidelines, or policies we may provide in writing or on our website. By creating an API or by explicitly agreeing to these Terms, you agree to be bound by these Terms. If you create a Plugin on behalf of another person or entity, you represent that you have the authority to agree to these Terms on their behalf.\n\n2. Plugins\n(a) Access. We may: (i) access and use your API to enable your Plugin within the Services; and (ii) allow our users to access and use your Plugin to retrieve information or take action on your website or application through the Services. We will not: (i) use your API to modify, translate, or create derivative works of your API; (ii) lease, distribute, pledge, assign, or otherwise transfer rights to your API to any third party; or (iii) intentionally interfere with or disrupt your API or any of its security measures.\n\n(b) Plugin Requests. The Services will send a request to your API containing information on behalf of a user of the Services (“Plugin Request”). If you have entered into a separate agreement with a user to process their information contained in a Plugin Request, then the terms of that separate agreement apply. Otherwise, you may only collect, use, store, transmit, and process Plugin Requests (i) in accordance with all applicable laws; and (ii) only as necessary to respond to or follow the instructions of the Plugin Request or to comply with applicable law. We are not responsible for any content or information from users or other Plugins that is sent to your API.\n\n(c) Plugin Responses. When your API receives a Plugin Request, it will send information or content back to the Services (“Plugin Response”). You are responsible for ensuring your Plugin Responses and API comply with all applicable laws and our Usage Policies. You grant us a worldwide, nonexclusive, royalty-free license to use, store, copy, translate, display, modify, and distribute all or any part of the Plugin Response to enable your Plugin to function within the Services. Upon termination of these Terms or if you remove your Plugin from the Services, we may continue to use Plugin Responses to maintain users’ Service history. You represent and warrant that you have obtained and will maintain all necessary rights (including from your users) to grant us these rights and to operate your Plugin. Except for the license rights granted in these Terms, you retain all rights in your API and Plugin Responses.\n\n(d) Plugin Reviews. While we are not obligated to monitor Plugins or their content, we may at any time: (i) review or test your Plugin to ensure quality and compliance with these Terms; or (ii) remove or refuse to display any content that violates these Terms. We may refuse to include any Plugin in our Services and may remove any Plugin from our Services at any time for any reason. Any information you give to us will be accurate and up-to-date.\n\n(e) Restrictions. Your API and Plugin Responses will not ...
#  Document(id_='2f6d6723-c1c2-4427-b42d-4428d8c26fa0', embedding=None, metadata={'file': '06_business-terms.txt', 'name': 'business terms'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Business terms\nUpdated\nNovember 14, 2023\n(Previous versions)\n\nThese OpenAI Business Terms govern use of our APIs, ChatGPT Enterprise, ChatGPT Team, and other services for businesses and developers. Use of our services for individuals, such as ChatGPT or DALL·E, are governed by the Terms of use.\n\n\nThank you for choosing OpenAI!\n\nThese Business Terms are an agreement between OpenAI, L.L.C. and you (“Customer”) that governs your use of our Services (as defined below). If you reside within a European Economic Area country or Switzerland, your agreement is with OpenAI Ireland Ltd. By signing up to use the Services, you agree to be bound by these Business Terms. You represent to us that you are lawfully able to enter into contracts and, if you are entering into these Business Terms for an entity, that you have legal authority to bind that entity. These Business Terms also refer to and incorporate the Service Terms, Sharing & Publication Policy, Usage Policies, and any other guidelines or policies we may provide in writing (the “OpenAI Policies”) and any ordering document signed by you and OpenAI or OpenAI webpage that you use to purchase the Services (an “Order Form”) (collectively, the “Agreement”).\n\n1. Services\n1.1 Use of Services. We grant you a non-exclusive right to access and use the Services during the Term (as defined below). This includes the right to use OpenAI’s application programming interfaces (“APIs”) to integrate the Services into your applications, products, or services (each a “Customer Application”) and to make Customer Applications available to End Users (as defined below). “Services” means any services for businesses and developers we make available for purchase or use, along with any of our associated software, tools, developer services, documentation, and websites, but excluding any Third Party Offering.\n\n1.2 Third-Party Offering. Third parties may offer products, services, or content through the Services (“Third Party Offering”). If you elect, in your sole discretion, to access or use a Third Party Offering (including by making it available via a Customer Application), your access and use of the Third Party Offering is subject to this Agreement and any additional terms applicable to the Third Party Offering.\n\n1.3 Responsibilities for Your Account. You must provide accurate and up-to-date account information. You are responsible for all activities that occur under your account, including the activities of any end user (each, an “End User”) who is provisioned with an account under your account (an “End User Account”) or accesses the Services through your Customer Application. You may not make account access credentials available to third parties, share individual login credentials between multiple users on an account, or resell or lease access to your account or any End User Account. You will promptly notify us if you become aware of any unauthorized access to or use of your account or our Services.\n\n2. Restrictions\nWe own all right, title, and interest in and to the Services. You only receive rights to use the Services as explicitly granted in this Agreement. You will not, and will not permit End Users to:\n\n(a) use the Services or Customer Content (as defined below) in a manner that violates any applicable laws or OpenAI Policies;\n\n(b) use the Services or Customer Content in a manner that infringes, misappropriates, or otherwise violates any third party’s rights;\n\n(c) send us any personal information of children under 13 or the applicable age of digital consent or allow minors to use our Services without consent from their parent or guardian;\n\n(d) reverse assemble, reverse compile, decompile, translate, engage in model extraction or stealing attacks, or other ...
#  Document(id_='16920852-c75a-4909-99e2-ff03fdd3458e', embedding=None, metadata={'file': '07_usage-policies.txt', 'name': 'usage policies'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Usage policies\nUpdated\nJanuary 10, 2024\nWe’ve updated our usage policies to be more readable and added service-specific guidance.\n\n\n\nWe aim for our tools to be used safely and responsibly, while maximizing your control over how you use them. By using our services, you agree to adhere to our policies.\n\nWe have established universal policies applicable to all our services, as well as specific policies for builders who use ChatGPT or our API to create applications for themselves or others. Violating our policies could result in action against your account, up to suspension or termination. We also work to make our models safer and more useful, by training them to refuse harmful instructions and reduce their tendency to produce harmful content. \n\nWe believe that learning from real-world use is a critical component of creating and releasing increasingly safe AI systems. We cannot predict all beneficial or abusive uses of our technology, so we proactively monitor for new abuse trends. Our policies will evolve based on what we learn over time.\n\nUniversal Policies\nTo maximize innovation and creativity, we believe you should have the flexibility to use our services as you see fit, so long as you comply with the law and don’t harm yourself or others. When using any OpenAI service, like ChatGPT, labs.openai.com, and the OpenAI API, these rules apply:\n\nComply with applicable laws – for example, don’t compromise the privacy of others,  engage in regulated activity without complying with applicable regulations, or promote or engage in any illegal activity, including the exploitation or harm of children and the development or distribution of illegal substances, goods, or services.\nDon’t use our service to harm yourself or others – for example, don’t use our services to promote suicide or self-harm, develop or use weapons, injure others or destroy property, or engage in unauthorized activities that violate the security of any service or system. \nDon’t repurpose or distribute output from our services to harm others – for example, don’t share output from our services to defraud, scam, spam, mislead, bully, harass, defame, discriminate based on protected attributes, sexualize children, or promote violence, hatred or the suffering of others.\nRespect our safeguards - don’t circumvent safeguards or safety mitigations in our services unless supported by OpenAI (e.g., domain experts in our Red Teaming Network) or related to research conducted in accordance with our Sharing & Publication Policy.  \nWe report apparent child sexual abuse material (CSAM) to the National Center for Missing and Exploited Children.\n\nBuilding with the OpenAI API Platform\nThe OpenAI Platform allows you to build entirely custom applications. As the developer of your application, you are responsible for designing and implementing how your users interact with our technology. To make this easier, we’ve shared our Safety best practices, and offer tools like our Moderation Endpoint and customizable system messages. \n\nWe recognize that our API introduces new capabilities with scalable impact, so we have service-specific policies that apply to all use of our APIs in addition to our Universal Policies:\n\nDon’t compromise the privacy of others, including:\na. Collecting, processing, disclosing, inferring or generating personal data without complying with applicable legal requirements\nb. Using biometric systems for identification or assessment, including facial recognition\nFacilitating spyware, communications surveillance, or unauthorized monitoring of individuals\nDon’t perform or facilitate the following activities that may significantly impair the safety, wellbeing, or rights of others, including:\na. Providing tailored legal, medical ...
#  Document(id_='6bfe6354-94fc-4a71-aff6-a54362d5a486', embedding=None, metadata={'file': '08_enterprise-privacy-at-openai.txt', 'name': 'enterprise privacy at openai'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text="Enterprise privacy at OpenAI\nUpdated\nJanuary 10, 2024\nTrust and privacy are at the core of our mission at OpenAI. We’re committed to privacy and security for ChatGPT Team, ChatGPT Enterprise, and our API Platform.\n\nOur commitments\nOwnership: You own and control your data\nWe do not train on your business data (data from ChatGPT Team, ChatGPT Enterprise, or our API Platform)\nYou own your inputs and outputs (where allowed by law)\nYou control how long your data is retained (ChatGPT Enterprise)\nControl: You decide who has access\nEnterprise-level authentication through SAML SSO (ChatGPT Enterprise and API)\nFine-grained control over access and available features\nCustom models are yours alone to use and are not shared with anyone else\nSecurity: Comprehensive compliance\nWe’ve been audited for SOC 2 compliance (ChatGPT Enterprise and API)\nData encryption at rest (AES-256) and in transit (TLS 1.2+)\nVisit our Trust Portal to understand more about our security measures\nGeneral FAQ\n\nHow can I use OpenAI technology in my business?\nThe easiest way to get started with OpenAI is to deploy ChatGPT Team or ChatGPT Enterprise for your employees. It’s simple to use and allows anyone in your organization to be productive with AI. If your engineering teams wish to build custom solutions using our technology, try our API Platform.\n\n\nDoes OpenAI train its models on my business data?\nNo. We do not use your ChatGPT Team, ChatGPT Enterprise, or API data, inputs, and outputs for training our models.\n\n\nWhat if I use GPTs in ChatGPT Enterprise or ChatGPT Team?\nYour end users can build and share GPTs internally with each other within your workspace. The same commitments we provide for ChatGPT Enterprise and ChatGPT Team also apply to your use of GPTs within those workspaces. Note that if your workspace admins enable GPTs to be shareable with the public, any GPTs that your users choose to publish externally are subject to review for abuse and misuse. Learn more about GPTs.\n\n\nWho owns inputs and outputs?\nAs between you and OpenAI: you retain all rights to the inputs you provide to our services and you own any output you rightfully receive from our services to the extent permitted by law. We only receive rights in input and output necessary to provide you with our services, comply with applicable law, and enforce our policies.\n\n\nHow does OpenAI ensure data security?\nOpenAI encrypts all data at rest (AES-256) and in transit (TLS 1.2+), and uses strict access controls to limit who can access data. Our security team has an on-call rotation that has 24/7/365 coverage and is paged in case of any potential security incident. We offer a Bug Bounty Program for responsible disclosure of vulnerabilities discovered on our platform and products. Please visit our Trust Portal for more details.\n\n\nCan OpenAI support my compliance with GDPR and other privacy laws?\nYes, we are able to execute a Data Processing Addendum (DPA) with customers for their use of ChatGPT Team, ChatGPT Enterprise, and the API in support of their compliance with GDPR and other privacy laws. Please complete our DPA form to execute a DPA with OpenAI.\n\n\nDoes OpenAI review my business data?\nWe may run any business data submitted to OpenAI’s services through automated content classifiers and safety tools, including to better understand how our services are used. The classifications created are metadata about the business data but do not contain any of the business data itself. Business data is only subject to human review as described below on a service-by-service basis.\n\nChatGPT Enterprise FAQ\n\nWhat is ChatGPT Enterprise?\nBuilt for businesses, ChatGPT Enterprise offers organizations the ability to use ChatGP ...
#  Document(id_='a7e25681-ff37-4361-962e-2fd4e9b412d5', embedding=None, metadata={'file': '09_sharing-and-publication-policy.txt', 'name': 'sharing and publication policy'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Sharing & publication policy\nUpdated\nNovember 14, 2022\nContents\nSocial media, livestreaming, and demonstrations\nContent co-authored with the OpenAI API\nResearch\n\nSocial media, livestreaming, and demonstrations\nTo mitigate the possible risks of AI-generated content, we have set the following policy on permitted sharing.\n\nPosting your own prompts or completions to social media is generally permissible, as is livestreaming your usage or demonstrating our products to groups of people. Please adhere to the following:\n\nManually review each generation before sharing or while streaming.\nAttribute the content to your name or your company.\nIndicate that the content is AI-generated in a way no user could reasonably miss or misunderstand.\nDo not share content that violates our Content Policy or that may offend others.\nIf taking audience requests for prompts, use good judgment; do not input prompts that might result in violations of our Content Policy.\nIf you would like to ensure the OpenAI team is aware of a particular completion, you may email us or use the reporting tools within Playground.\n\nRecall that you are interacting with the raw model, which means we do not filter out biased or negative responses. (Also, you can read more about implementing our free Moderation endpoint here.)\nContent co-authored with the OpenAI API\nCreators who wish to publish their first-party written content (e.g., a book, compendium of short stories) created in part with the OpenAI API are permitted to do so under the following conditions:\n\nThe published content is attributed to your name or company.\nThe role of AI in formulating the content is clearly disclosed in a way that no reader could possibly miss, and that a typical reader would find sufficiently easy to understand.\nTopics of the content do not violate OpenAI’s Content Policy or Terms of Use, e.g., are not related to adult content, spam, hateful content, content that incites violence, or other uses that may cause social harm.\nWe kindly ask that you refrain from sharing outputs that may offend others.\nFor instance, one must detail in a Foreword or Introduction (or some place similar) the relative roles of drafting, editing, etc. People should not represent API-generated content as being wholly generated by a human or wholly generated by an AI, and it is a human who must take ultimate responsibility for the content being published.\n\nHere is some stock language you may use to describe your creative process, provided it is accurate:\n\nThe author generated this text in part with GPT-3, OpenAI’s large-scale language-generation model. Upon generating draft language, the author reviewed, edited, and revised the language to their own liking and takes ultimate responsibility for the content of this publication.\nResearch\nWe believe it is important for the broader world to be able to evaluate our research and products, especially to understand and improve potential weaknesses and safety or bias problems in our models. Accordingly, we welcome research publications related to the OpenAI API.\n\nIf you have any questions about research publications based on API access or would like to give us advanced notice of a publication (though not required), please email us at papers@openai.com.\n\nIn some cases, we may want to highlight your work internally and/or externally.\nIn others, such as publications that pertain to security or misuse of the API, we may want to take appropriate actions to protect our users.\nIf you notice any safety or security issues with the API in the course of your research, we ask that you please submit these immediately through our Coordinated Vulnerability Disclosure Program.\nResearcher Access Program\nThe ...
#  Document(id_='5011cfc0-cf1d-4ca9-b43f-d298889ab09a', embedding=None, metadata={'file': '10_coordinated-vulnerability-disclosure-policy.txt', 'name': 'coordinated vulnerability disclosure policy'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Coordinated vulnerability disclosure policy\nUpdated\nJuly 28, 2023\nSecurity is essential to OpenAI’s mission. We value the input of hackers acting in good faith to help us maintain a high standard for the security and privacy for our users and technology. This includes encouraging responsible vulnerability research and disclosure.\n\nBug bounty\nThe OpenAI Bug Bounty Program is a way for us to recognize and reward the valuable insights of security researchers who contribute to keeping our technology and company secure. We invite you to report vulnerabilities, bugs, or security flaws you discover in our systems. By sharing your findings, you will play a crucial role in making our technology safer for everyone.\n\nDetailed guidelines and rules for participation can be found on our Bug Bounty Program page.\n\nIncident reporting\nTo report a security incident, please let us know immediately by submitting an encrypted report. Information shared with us in this manner must be shared unconditionally.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
# Define a text chunking procedure
text_chunker = SentenceSplitter(chunk_size=128, chunk_overlap=8)

# Split the documnets into nodes
nodes = text_chunker.get_nodes_from_documents(documents)

# Load a model for embedding the text
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# /home/maruanottoni/miniconda3/envs/nn/lib/python3.8/site-packages/torch/cuda/__init__.py:128: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11080). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
output_dir = './bge-small-en-v1.5_openai-tos_vectors/'

# %%
## Generate indexing vectors

if True:
    index = VectorStoreIndex(
        nodes,
        embed_model=embed_model,
        show_progress=True
    )

    ## Save embeddings with a storage context.
    index.storage_context.persist(persist_dir = output_dir)

## Load embeds from storage context. Requires setting the same storage_context as when generated.
else:
    storage_context = StorageContext.from_defaults(persist_dir = output_dir)
    index = load_index_from_storage(
        storage_context=storage_context,
        embed_model=embed_model
    )
# Out:
# Generating embeddings:   0%|          | 0/326 [00:00<?, ?it/s]

# %%
## Create a simple query engine and compare to GPT responses

def gpt_and_rag_answers(query,query_engine,llm_engine):
    llm_response = llm_engine.complete(query)
    rag_response = query_engine.query(query)

    print(f'############\nGPT-3 response:\n{llm_response}\n\n############\nRAG response:\n{rag_response}')
    return llm_response, rag_response

## Create a GPT-4 object for API calls
llm_gpt3 = OpenAI(model='gpt-3.5-turbo-0125',temperature=0.0)
query_engine = index.as_query_engine(llm=llm_gpt3)

# %%
query = 'Who owns the content created by OpenAI programs?'
gpt, rag = gpt_and_rag_answers(query, query_engine, llm_gpt3)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ############
# GPT-3 response:
# OpenAI retains ownership of the content created by its programs. Users are granted a license to use the content generated by OpenAI's programs, but the ownership rights remain with OpenAI.
#
# ############
# RAG response:
# You retain ownership rights in the input, and you own the output created by OpenAI programs.

# %% [markdown]
# ## Improved RAG Querying

# %%
## Create improved querying engine

## Set number of nodes for use in generation
TopK = 5

## Improve the prompting template to give more verbose answers
qa_prompt_tmpl = PromptTemplate(
    "You are an expert Q&A system that is trusted around the world."
    "Always answer the query using the provided context information, and not prior knowledge.\n"
    "Context information is below.\n"
    "---------------------\n"
    "{context_str}\n"
    "---------------------\n"
    "Given the context information and not prior knowledge, answer the query.\n"
    "Query: {query_str}\n"
    "Answer: "
)

###################

## Define the larger-k retriever
retriever = VectorIndexRetriever(
    index=index,
    similarity_top_k=TopK,
)

## Set the form of context consolidation
response_synthesizer = get_response_synthesizer(response_mode=ResponseMode.SIMPLE_SUMMARIZE)

## Build the improved query engine and set the template to the new one.
custom_query_engine = RetrieverQueryEngine.from_args(
    retriever,
    response_synthesizer=response_synthesizer,
)
custom_query_engine.update_prompts(
     {"response_synthesizer:text_qa_template": qa_prompt_tmpl}
)

###################

## Create a GPT-4 generator.
llm_gpt4 = OpenAI(model='gpt-4',temperature=0.0)

# %%
## Run the query again with the improved engine.

query = 'Who owns the content created by OpenAI programs?'
gpt, rag = gpt_and_rag_answers(query, custom_query_engine, llm_gpt3)
# Out:
# ############
# GPT-3 response:
# OpenAI retains ownership of the content created by its programs. However, OpenAI has released some of its models and tools under open-source licenses, allowing others to use and modify the content created by these programs.
#
# ############
# RAG response:
# As per the provided context information, the content created by OpenAI programs is owned by the user who provided the input and received the output. The user retains ownership rights in the input and owns the output generated by the OpenAI program. OpenAI assigns to the user all rights, title, and interest in and to the output.

# %% [markdown]
# ## Re-ranking

# %%
## Create a querying engine with re-ranking

## Set the re-ranker parameters
Rerank_TopK = 20
Rerank_TopRRK = 5

###################

## Define the re-ranking retriever.
retriever_rr = VectorIndexRetriever(
    index=index,
    similarity_top_k=Rerank_TopK,
)

## Set the form of context consolidation
response_synthesizer_rr = get_response_synthesizer(response_mode=ResponseMode.SIMPLE_SUMMARIZE)

## Build the re-ranking query engine and set the template to the new one.
custom_query_engine_rerank = RetrieverQueryEngine.from_args(
    retriever_rr,
    response_synthesizer=response_synthesizer_rr,
    node_postprocessors=[
        LLMRerank(
            choice_batch_size=5,
            top_n=Rerank_TopRRK,
        )],
)
custom_query_engine_rerank.update_prompts(
     {"response_synthesizer:text_qa_template": qa_prompt_tmpl}
)

# %%
## Test a more complex question to show benefit of re-ranking. First with just the improved engine.

query = 'Will OpenAI give me any sort of reward if I find an issue with their software?'

gpt, rag = gpt_and_rag_answers(query, custom_query_engine, llm_gpt4)
# Out:
# ############
# GPT-3 response:
# OpenAI has not publicly stated that they offer rewards for finding issues with their software. However, they would likely appreciate any feedback or bug reports that could help improve their systems. It's always a good idea to reach out to them directly for more information.
#
# ############
# RAG response:
# OpenAI does not mention providing rewards for finding issues with their software in the provided context information.

# %%
## Next, using the re-ranking engine.

query = 'Will OpenAI give me any sort of reward if I find an issue with their software?'

gpt, rag_rr = gpt_and_rag_answers(query, custom_query_engine_rerank, llm_gpt4)
# Out:
# ############
# GPT-3 response:
# OpenAI has not publicly stated that they offer rewards for finding issues with their software. However, they would likely appreciate any feedback or bug reports that help improve their systems. It's always a good idea to reach out to them directly for accurate information.
#
# ############
# RAG response:
# Yes, OpenAI offers a Bug Bounty Program as a way to recognize and reward security researchers who contribute to keeping their technology and company secure.

# %% [markdown]
# ## Fine-tuning

# %%
## Create train and test splits with the nodes.
train_nodes, val_nodes = train_test_split(pd.Series(nodes), test_size=0.20, random_state=7)
print(len(train_nodes), len(val_nodes))
# Out:
# 260 66

# %%
## Generate Q&A pairs from the training set. This operates by looking at each
## node in the train set, and using GPT to generate a question answered by that
## node.

json_locs = './bge-small-en-v1.5_openai-tos_qa-embedding-pairs/'
# !mkdir $json_locs

if True:
    train_dataset = generate_qa_embedding_pairs(
        train_nodes,
        llm=OpenAI(model='gpt-3.5-turbo',temperature=0.0),
    )
    val_dataset = generate_qa_embedding_pairs(
        val_nodes,
        llm=OpenAI(model='gpt-3.5-turbo',temperature=0.0),
    )

    train_dataset.save_json(json_locs+"train_dataset.json")
    val_dataset.save_json(json_locs+"val_dataset.json")

else:
    train_dataset = EmbeddingQAFinetuneDataset.from_json(json_locs+"train_dataset.json")
    val_dataset = EmbeddingQAFinetuneDataset.from_json(json_locs+"val_dataset.json")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100%|██████████| 260/260 [04:02<00:00,  1.07it/s]
# 100%|██████████| 66/66 [01:05<00:00,  1.00it/s]

# %%
## Look at validation set queries and find an interesting example. Copy/paste a
## query ID into the next cell to see the Q&A.
val_dataset.__dict__['queries']
# Out:
# {'82ba378a-a109-48c3-978f-ae9955876bdb': 'How can users report GPTs that violate the Usage Policies according to the document?',
#  'ba918d22-475e-431e-9ff1-762f2cde874b': 'What precaution should users take when using GPTs with the name "GPT" in it, as mentioned in the document?',
#  'deec483c-6d22-4404-b03d-9fe27c3974c0': 'How does the agreement define Confidential Information and what is included in this category according to the context provided?',
#  'f2fb3518-2d98-488a-b4bc-7a028cb33fa5': "What are the three key obligations that the Recipient agrees to regarding the use and protection of the Discloser's Confidential Information in the agreement?",
#  '2c4b63c6-a9ea-457a-8eca-fcbefaf8288b': 'How has the App Review process been updated in 2022, and what is the new approach that developers need to follow?',
#  '9805699e-4f43-4543-bf93-923854c90667': 'What changes have been made to the Safety Best Practices, and how do these changes impact developers submitting apps for review?',
#  'ea5db060-8d87-46a9-8a6c-e8a4dc636113': 'How does OpenAI ensure data security both at rest and in transit?',
#  '2012a9cc-6c5b-452e-8271-f494ceeb34bb': 'What measures does OpenAI have in place to address potential security incidents, and how do they encourage responsible disclosure of vulnerabilities on their platform?',
#  'f493b8ea-34fa-47b4-bc0b-fca40d80a3c9': 'What are the restrictions and guidelines outlined in the document regarding the use of OpenAI Trademarks for promoting a Plugin?',
#  '3ef77273-eee4-4c58-a80e-31f2abc896a6': 'Why is it important to obtain prior written consent from OpenAI before implying their support or endorsement of a Plugin that uses their trademarks?',
#  'e841cf50-290d-43de-8663-3b9fedf93b9f': 'How does the document address the potential interruptions, accuracy, and errors related to the plugin feature and services?',
#  '83547237-e0d9-4a07-931b-85250d866fc0': 'In what way does the document discuss the limitations of liability in relation to the content or information being secure, lost, or altered?',
#  '427f6de2-ee28-4e48-a304-46d68b686457': 'What are the three options available to OpenAI in response to a customer objection regarding the use of a Subprocessor for processing Customer Data?',
#  'ff7649b9-8203-42e6-a80a-780685889f3d': 'How does the document outline the potential actions that OpenAI and the customer can take in response to objections raised about the use of a Subprocessor?',
#  'a62885b3-1b92-4cf0-8029-4941d75c9d72': 'How does the clause regarding the use of Input or fine-tuning files relate to potential copyright infringement claims?',
#  'aeb791a0-5636-46d2-afb3-5ee6c1781712': 'In what circumstances would a claim of trademark violation be applicable based on the use of Output in trade or commerce?',
#  '04bc61a0-ca49-4e3a-89ac-6807313c0151': 'What steps must an individual take if they wish to have an authorized agent act on their behalf in making a request to exercise their rights with OpenAI?',
#  'fb1c9283-8932-4801-a039-29af20d01ede': 'In what circumstances may an individual have the right to appeal a decision made by OpenAI regarding their request to exercise their rights under applicable local law?',
#  '426f3755-b432-433a-bbd8-e14a89d2548f': 'What are the options for conducting the arbitration process as outlined in the document?',
#  '00b6990f-abcf-480b-b9e5-e05ab8c150ae': 'In the event that a claim is deemed frivolous, what are the responsibilities of the party making the claim according to the arbitration procedures?',
#  '7e75638e-6818-4e9b-b011-f2ad272c9703': 'How does the company disclose personal information to third parties, and under what circumstances are they required to notify the individual?',
#  '0f1c1826-1f7e-4e5b-ad88-ecc2c34e18ee': 'Can you provide examples of the types of vendors and service providers that may receive Personal Information from the company, as mentioned in the document?',
#  '8cc30e58-afa6-41d9-9649-c56efb757614': 'How does the agreement between the parties address the issue of selling Customer Data in relation to the CCPA and U.S. Privacy Laws?',
#  'a21e692b-62b1-4860-a2b5-ef7d83687d74': 'What is the responsibility of OpenAI in regards to informing the Customer if an instruction violates applicable Data Protection Laws?',
#  '6b1d96d1-7495-4c1d-8b04-f7df1a2a4e34': 'How does OpenAI ensure the security of its systems, data, and Customer Data according to the information security program described in the Addendum?',
#  'bb2c2b6d-b800-4a45-ac5b-c8f5b20ab00d': 'Can you explain the significance of maintaining security standards for the Services and handling of Customer Data as outlined in the document?',
#  'bfd22967-b6dd-4cbf-a517-51f241f8d88c': 'What steps must be taken by both parties before formal legal action can be pursued in the event of a Dispute?',
#  'ad2a4273-b957-4731-aca3-b34b81ade819': 'What is the next course of action if a Dispute cannot be resolved informally within 60 days according to the provided information?',
#  '9d627c51-6b8c-45f1-897d-5540fb81d4fa': 'How does OpenAI handle the disclosure of Personal Information to its affiliates, and what guidelines do they follow in sharing this information?',
#  '8154d210-60d1-4d42-b7b2-2c9c39f4c548': 'In what circumstances are Business Account Administrators allowed to access and control OpenAI accounts, and what implications does this have for users of ChatGPT Enterprise or business accounts?',
#  '43d8d8fd-0ba3-4280-bbd8-e15f7783bb89': 'How do export control laws and regulations play a role in the Terms outlined in the document?',
#  'a9e2b411-86b5-450d-882f-16049bb9485e': 'In what circumstances would an amendment to the Terms need to be in writing, according to the document?',
#  '6aad9aa7-9650-44b6-bb6a-e6a2b7fe3fa5': 'How should a developer handle Plugin Requests in accordance with the terms outlined in the document?',
#  '9c7345e4-b42e-4828-939a-6ed496f3d6fc': 'What responsibilities does a developer have in processing Plugin Responses according to the guidelines mentioned in the document?',
#  '09b8cbdd-b0f6-4268-bb3f-4527ecf2da25': 'What are the responsibilities associated with sharing account credentials according to the Terms provided?',
#  '2f2e5413-215d-44b2-bfe4-245ec528f9a3': 'If you are creating an account or using the Services on behalf of another person or entity, what requirement must you meet according to the Terms?',
#  'b11e4556-df43-45cc-be05-90ca5291e3d7': 'How does the high volume of requests impact the review process for applications seeking subsidy?',
#  'ee6cb42f-902c-429a-9192-e3d91de4a444': 'What criteria are used to determine which research applications will be selected for subsidy?',
#  'dba737a7-4c86-4fa9-a6bf-df4b74ce96fd': "How can a writer ensure that their content does not violate OpenAI's Content Policy or Terms of Use?",
#  '8f52f03c-0910-40a4-8977-21cebbf0f8ae': 'In what ways can a writer ensure that their content does not offend others, as requested in the context information provided?',
#  'c51db012-61ab-447f-8d3b-a983f3901a2e': 'How can a developer ensure they are not compromising the privacy of others when using ChatGPT, specifically in terms of collecting and processing personal data?',
#  'afa56477-7bf3-451b-938e-750a25210e2f': 'In what ways does the service-specific policy for ChatGPT prohibit the solicitation or collection of sensitive identifiers and security information?',
#  '6c81ab4f-3524-478d-ae16-7ab6d576d2aa': "How can prompt design and fine-tuning be utilized to increase the alignment of a model's objective with human preferences in research use cases?",
#  '29fdf64a-0592-467a-a219-6f48ec4b02df': 'In what ways can researchers determine the objective that a model is best understood as pursuing, and how can this understanding be improved to better align with human preferences?',
#  '9c593d37-98d5-4fbc-ab3d-216b24701b14': 'What does the company warrant in regards to the Services during the Term of the agreement?',
#  'c5b995f7-742d-46bd-8723-3faa8754d491': 'How does the company disclaim any warranties in the context of the Services provided?',
#  '5ca4b9a4-61f5-4d6d-aec2-3a68095f608b': 'How does OpenAI ensure compliance with data protection requirements when engaging Subprocessors?',
#  '9b2b771e-8b23-4fce-a541-198669f54e91': 'In the context of the CCPA, what restrictions are placed on OpenAI in terms of retaining, using, disclosing, or processing Customer Data?',
#  '9696d83d-8542-4773-b5cd-477366ffb788': 'How does the Federal Arbitration Act impact the interpretation and enforcement of arbitration terms in the activities described in the Terms?',
#  'a889b7a7-909a-4ca5-acd4-ecc0564166e3': "Under what circumstances will OpenAI seek attorneys' fees and costs in arbitration according to the provided information?",
#  '7c60a255-729c-4557-9fc3-0c1be28e7190': 'How does the agreement address liability for failures or delays resulting from conditions beyond the control of either party, and what specific examples are given in the document?',
#  '4ccdbb20-1e6a-4863-b166-ae28013247f1': 'Under what circumstances can this Agreement be assigned, and who has the authority to make such an assignment without notice or consent?',
#  '2ca281c8-5084-4101-ac09-3c90565d39ed': 'What precautions should users take before enabling a Plugin according to the provided context information?',
#  '80fc1957-cc9a-4048-b33a-7e496f390b42': 'How does the Services handle user data when a Plugin is enabled, as described in the document?',
#  'cec9e17a-f8e3-4cf8-a75d-3f255283c137': 'How does the company ensure the safety and usefulness of their AI models, and what actions could be taken against accounts that violate their policies?',
#  'f7ecef09-cba7-432c-9812-40b0be25583e': 'How does the company approach the evolution of their policies regarding the use of AI technology, and what measures do they take to proactively monitor for new abuse trends?',
#  'e093dd7a-9fe8-48d6-9d04-599a1e58abc6': 'What authority does the arbitrator have in resolving Disputes, and are there any exceptions to this authority according to the document?',
#  '9f05e672-152c-421d-bd39-6b86897d8de9': 'In what circumstances do the state or federal courts of San Francisco, California have the authority to intervene in Disputes, as outlined in the document?',
#  '4c6736e4-725c-4eaa-9d9c-ae2dd503ad79': 'How does the company disclose the categories of Personal Information they collect, according to the additional U.S. state disclosures provided in the document?',
#  '0d0006c7-31e0-411c-b2ec-cf9b06d1fec3': "What steps can individuals take to exercise their rights with respect to the data collected from the internet to train the company's models, as mentioned in the help center article referenced in the document?",
#  '62ddf7c5-292f-4481-abe3-db14771f68ca': 'How can claims arising from the combination of Services with products, services, or software not provided by the company be excluded from liability?',
#  'f55b498d-5a2b-4283-a4a9-2991f9a78936': 'In what circumstances would claims related to Customer Applications not be covered under the agreement?',
#  'f1969538-26e3-4081-8fc5-7d4918cede45': 'How does OpenAI ensure that persons employed by them and other persons engaged to perform on their behalf comply with data protection obligations and maintain confidentiality with respect to Customer Data?',
#  'c54f8d15-ca60-4963-95a8-2b5235b62f51': "What is the significance of engaging subprocessors listed on the OpenAI platform to process Customer Data, and how does this relate to OpenAI's data protection obligations under the Agreement and the DPA?",
#  '29a87408-1db6-4946-a85e-fcb523255ae1': 'Who within an organization can view conversations and chat history in ChatGPT Enterprise?',
#  'caf9d261-b8b8-4f5d-a33b-528aa781241d': 'Under what circumstances would authorized OpenAI employees access conversations in ChatGPT Enterprise?',
#  '0a0835df-ba56-41fb-87d5-0e2ad7e8526a': 'How can red teaming approaches help AI developers think about responsibly deploying technologies like the API? Provide examples of potential misuse scenarios and strategies to mitigate them.',
#  '7234c79f-966b-4167-a161-643bbd557d1f': 'In what ways can model exploration of the capabilities served by the API contribute to advancing our understanding of AI systems? Discuss the importance of identifying concepts, extracting latent knowledge, and predicting future behavior in this context.',
#  '11a8152a-4e29-435e-bf3b-7bcd9d65725b': 'How does OpenAI ensure compliance with Data Protection Laws when processing Customer Data for reasons other than in connection with the Agreement?',
#  '7ed89746-1eaa-4b97-b2ad-7eb673c80332': 'Describe the security measures that OpenAI is required to maintain according to the agreement.',
#  'fb8ce0ce-0772-4cbe-95a0-881b877a345d': 'How can users ensure that the OpenAI team is made aware of a particular completion?',
#  'a85d8ea0-b07a-422c-9828-e702f3dbf989': 'What is the significance of interacting with the raw model in terms of filtering biased or negative responses?',
#  'cbb73410-9af1-40f2-978a-b9c9fff6e807': 'How does the OpenAI Platform support developers in designing and implementing user interactions with their technology?',
#  'f3ea3635-9037-46fa-b304-f0b4ed9c99e9': 'Why is it important for developers to adhere to safety best practices and utilize tools like the Moderation Endpoint when building custom applications with the OpenAI Platform?',
#  '4bbf7394-d401-4fb8-aafa-566e0fa8b8f2': 'What happens to any rights or obligations, including the payment of amounts due, that have accrued under the Agreement up to the date of termination or expiration?',
#  '21c03bad-0a90-45d0-ac2f-a574a5f8afcc': 'How long does the company have to delete all Customer Content from their systems upon termination of the Agreement, unless legally required to retain it?',
#  '6c258e65-c9f6-4a33-a6f8-2b1efbf5cc37': 'How does enabling the plugin impact the handling of Plugin Data and its transfer to an Application?',
#  'd51d74b8-795b-4fa5-a65d-264d183cd4b6': 'What is the responsibility of the provider in terms of Plugin Data once it has been provided to an Application other than those owned by them?',
#  '15a06250-2b6e-4baf-90c3-2a4fe2d3a2bf': "What are the responsibilities of Administrators in ChatGPT Enterprise in terms of managing End Users' access and content within the organization's workspace?",
#  '9c78d021-53ba-4218-b722-74779dbc8609': 'How does the concept of output indemnity relate to the actions and responsibilities of Customers and End Users in the context of ChatGPT Enterprise?',
#  '5d94da35-06eb-43ae-8813-602ffce8cfc5': "What is the purpose of the Data Processing Addendum (DPA) mentioned in the context information, and how does it govern OpenAI's processing of Customer Data?",
#  'a905070e-90fe-4f0d-a6f6-eb58afcf37c7': 'Can you explain the specific services or platforms through which Customer Data is provided to OpenAI, as outlined in the document?',
#  '91d4fd4a-c3d7-47bc-9624-baa354ec47a6': 'How does the legal basis of "performance of a contract" apply to the processing of Personal Information in the context of providing and maintaining Services?',
#  'f56e50a1-8c89-4cb5-a982-a61b24f7c656': 'What potential consequences could arise if a user does not provide Account Information, Content, and Technical Information necessary for the provision of Services?',
#  '269a3283-4d88-433c-95a6-26ae7389eb88': 'How does the company handle payment for paid subscriptions, and what actions may be taken if a payment cannot be completed?',
#  '31be963a-ecfd-4b78-88bc-641934f723bc': 'What options are available for paying for Services in advance, and what are the terms and conditions associated with service credits?',
#  '54893475-820e-4a20-8eff-f64c7bac03ec': 'What are the key components that the Plugin Terms govern in relation to the creation and use of a Plugin with OpenAI Services?',
#  'eb08069c-16f7-4226-99f2-16a9c8428d7b': 'How does residency within the European Economic Area or Switzerland impact the agreement with OpenAI for the creation and use of a Plugin?',
#  '15e2b8a6-2b4b-4cc2-a5b5-e0e12168f668': "How does OpenAI's indemnification obligations to ChatGPT Enterprise customers differ when it comes to claims related to the use or distribution of Output that infringes a third party's intellectual property right?",
#  'ec170236-4919-46f4-80ad-eec7b2c212ed': "Under what circumstances does OpenAI's indemnity for claims related to the infringement of a third party's intellectual property right not apply to ChatGPT Enterprise customers?",
#  '4f0cdc90-33ec-47d9-a164-023e00479c42': 'What steps may be required in order to verify your credentials before submitting a request to know, correct, or delete Personal Information?',
#  '17155bb4-e353-4e22-a327-8f3a5c52b98f': 'Under what circumstances may you be asked to provide additional Personal Information and proof of residency for verification purposes when submitting a request related to your Personal Information?',
#  'a4a95bf7-cec1-4bdb-92ac-a19688b588e7': 'What information must be included in a written claim concerning copyright infringement, according to the provided context?',
#  '740e6e53-994f-496d-b933-f83d7d67b30c': 'As a General Counsel or Copyright Agent, what steps would you take upon receiving a claim of copyright infringement that includes the required information outlined in the document?',
#  '31e8023d-d6c8-476e-95d4-b02f1380d19b': 'What is the minimum age requirement to use the services provided by OpenAI, and what additional permission is needed for users under the age of 18?',
#  '54c00528-a54b-4fee-a8a3-9cfdfd22e3e4': "Why is it important for users to provide accurate and complete information when registering for an account to use OpenAI's services?",
#  'a7cd8ef3-612e-4a11-8017-cb8fa20953e3': 'How does the relationship between OpenAI and the individual described in the context differ from that of legal partners or independent contractors?',
#  '648e7b15-100a-4b24-8179-b782399eeb7d': 'Can either party assign or transfer their rights and obligations outlined in the Terms without prior written consent?',
#  'd6fe3c8e-30bb-4669-9c91-e6e3b20a217c': 'How does OpenAI address the possibility of providing incomplete, incorrect, or offensive Output through their Services?',
#  '68efbbaf-27d3-4183-88a3-263dd5a33208': "What are the requirements for providing billing information when purchasing OpenAI's Services?",
#  '1ecae83d-f957-436b-896b-7a58253a1b2f': "Who retains all rights to the inputs provided to OpenAI's services according to the context information?",
#  '4730450f-b7fc-45ae-85a3-60e7dbf69aed': 'What rights does OpenAI have in the input and output necessary to provide their services, as stated in the document?',
#  '9ab24b40-ad42-4b14-8882-a8997703e808': 'How can OpenAI models be adapted to specific tasks according to the context information provided?',
#  'aa65b967-da51-43b2-84d4-16128fb8adb1': 'What happens to the data submitted to fine-tune a model, as mentioned in the document?',
#  'b60771a7-b6da-4c6c-b207-69e0646601c7': 'How does OpenAI ensure compliance with privacy laws when processing Customer Data originating in the European Economic Area, according to the standard contractual clauses adopted by the EU Commission on June 4, 2021?',
#  '75b6bef3-7230-40d9-bb64-af2b426d79c0': 'In what scenario would Module Two (Controller to Processor) of the EU SCCs apply, and what roles do the Customer and OpenAI play in this context?',
#  '57342de9-ad5f-47f2-a72f-2cf5107e6ef6': 'How does OpenAI ensure the security of customer identities when accessing the Services, and what measures do they take to prevent storing user-provided passwords?',
#  'ed470d2c-1a04-4c51-b2f2-5f790b5fa13a': 'Can you explain how OpenAI maintains the security and organization of Customer Data within the Services, specifically in terms of logically separating data by organization account using unique identifiers?',
#  'aa1eb873-97fc-479a-9c67-f21242f570bc': 'What is the requirement for creating a Plugin on behalf of another person or entity, according to the Terms mentioned in the document?',
#  '58fd28d4-fa9e-49ca-ae9d-cbe9557bf867': 'How does the document outline the access and use of APIs for enabling Plugins within the Services, as described in section 2(a)?',
#  'ca8fa573-759d-4ef7-bc95-5a1cee10af23': 'How does ChatGPT Enterprise ensure data security and compliance with regulations?',
#  '8cd043b6-504b-4284-a158-278644c44850': 'What control measures are in place for data retention and access in ChatGPT Enterprise?',
#  'b9e1447f-e2f8-48b7-a08a-0b197cb1c59d': "How can individuals request a correction for factually inaccurate information about themselves in ChatGPT's output?",
#  'dd9d6bef-f381-43ce-937d-ba6185b9e1a2': "In what instances may OpenAI not be able to correct inaccuracies in ChatGPT's output, and what alternative option do individuals have in such cases?",
#  '1497ebbf-ef76-4185-a42b-fdbb6e1376bb': 'How does the prohibition against using the service to promote suicide or self-harm align with ethical considerations in the digital age?',
#  '971c98f6-1368-473a-8026-fb09e3986edb': 'In what ways can individuals inadvertently violate the terms of service by engaging in unauthorized activities that compromise the security of a service or system?',
#  'cf01d93b-ad11-492b-828d-e88ff65bf439': 'How does the company justify processing Account Information, Content, Social Information, and Technical Information for the purpose of protecting their Services from abuse, fraud, or security risks, or for developing, improving, or promoting their Services?',
#  '1778ca21-145d-4d72-a282-e9d9d40f6f64': 'In what circumstances would a user be required to give their consent for the processing of their Personal Information, and what rights do they have in relation to withdrawing that consent?',
#  '36d4e923-98e0-4ec4-aa61-957260af4689': 'How does the agreement mentioned in the context protect the recipient from damages and settlement amounts in case of a third party claim related to intellectual property infringement?',
#  '600382f5-d08b-4aaa-b89e-c6006b6412ed': 'Can you explain the significance of training data used to train a model that powers the Services in the context of defending and indemnifying against third party intellectual property claims?',
#  '8be2ad8c-c937-4f34-b5c1-39e1976b29ba': 'How does OpenAI handle Customer Data upon the termination of the Data Processing Agreement (DPA)?',
#  'ef6534e4-0de0-4040-9021-b474c5ba360a': "In what circumstances can OpenAI continue to process information derived from Customer Data after the DPA's termination?",
#  '74f74bfc-ea4c-44b3-9f13-afd452c6b4eb': 'How does the document specify the ability of OpenAI and creators of GPTs to make changes or remove GPTs from the service?',
#  '247d9018-dde2-4ab9-83a5-3bc655fb9b11': 'In what way does the document caution against using Image Capabilities for medical purposes, and what specific advice does it provide regarding the use of images with people in the service?',
#  'a721e066-4e40-4b2a-9d75-e8cf02589d00': 'Compare and contrast the key provisions of the Colorado Privacy Act, Connecticut’s Data Privacy Act, Utah Consumer Privacy Act, and Virginia Consumer Data Protection Act.',
#  'f79a9b64-2866-42ca-8e74-54c65dddfe9b': 'How do the U.S. privacy laws mentioned in the context information aim to protect consumer data and privacy rights?',
#  'dbc8467f-d38d-40ff-98b6-cf8fcd367766': 'What is the significance of the UK Addendum in relation to the Data Protection Act 2018?',
#  '729aa264-5cd6-4135-8a1f-08a2cc0453c0': "How does the issuance of the Information Commissioner's Office report relate to the requirements laid out in s119A of the Data Protection Act 2018?",
#  'c55cf5ea-4517-4b5f-a031-41f59c975242': 'How do the Service Terms govern the use of the Services, and what takes precedence in case of a conflict with the Agreement?',
#  'c9649f58-37e6-4a47-bcbc-3f1e7fccb3da': 'Define the term "Content" as used in the context of these Service Terms, and explain its relationship to "Customer Content."',
#  'beb3419a-2211-4510-b25c-72a44ae7dd62': 'How does compliance with privacy laws, such as the CCPA, impact OpenAI\'s classification as a "service provider" or "processor" under U.S. Privacy Laws?',
#  '02bcc0d4-6a7e-4ddf-9793-d5e1d900480a': 'What actions could potentially prevent OpenAI from being considered a "service provider" under the CCPA or a "processor" under U.S. Privacy Laws?'}

# %%
#query_id = '0155e8ac-0174-4336-abcc-0ed302230b13'
query_id = '02bcc0d4-6a7e-4ddf-9793-d5e1d900480a'
corpus_id = val_dataset.__dict__['relevant_docs'][query_id][0]

sample_chunk = val_dataset.__dict__['corpus'][corpus_id]
sample_query = val_dataset.__dict__['queries'][query_id]

print(f'Sample text node:\n------------------\n{sample_chunk}')
print(f'\n\nQuery based on node:\n---------------------\n{sample_query}')
# Out:
# Sample text node:
# ------------------
# Privacy Laws or a “share” under the CCPA (or equivalent concepts under U.S. Privacy Laws); or (ii) render OpenAI not a “service provider” under the CCPA or “processor” under U.S. Privacy Laws.
#
# 7.
#
#
# Query based on node:
# ---------------------
# What actions could potentially prevent OpenAI from being considered a "service provider" under the CCPA or a "processor" under U.S. Privacy Laws?

# %%
## Fine-tune the model with the training set. This will direct the
## model to find the node that each question was based off of.

model_ft_path = './bge-small-en-v1.5_openai-tos_finetuned_model'

finetune = True  # Set to False to load a pre-finetuned model

if finetune:
    finetune_engine = SentenceTransformersFinetuneEngine(
        model_id="BAAI/bge-small-en-v1.5",
        dataset=train_dataset,
        epochs=4,
        model_output_path=model_ft_path,
        val_dataset=val_dataset
    )
    finetune_engine.finetune()
    finetuned_embedding_model = finetune_engine.get_finetuned_model()
else:
    finetuned_embedding_model = HuggingFaceEmbedding(
        model_name_or_path=model_ft_path
    )
# Out:
# Currently using DataParallel (DP) for multi-gpu training, while DistributedDataParallel (DDP) is recommended for faster training. See https://sbert.net/docs/sentence_transformer/training/distributed.html for more information.
# /home/maruanottoni/miniconda3/envs/nn/lib/python3.8/site-packages/sentence_transformers/trainer.py:205: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `SentenceTransformerTrainer.__init__`. Use `processing_class` instead.
#   super().__init__(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 16
#       8 if finetune:
#       9     finetune_engine = SentenceTransformersFinetuneEngine(
#      10         model_id="BAAI/bge-small-en-v1.5",
#      11         dataset=train_dataset,
#    (...)
#      14         val_dataset=val_dataset
#      15     )
# ---> 16     finetune_engine.finetune()
#      17     finetuned_embedding_model = finetune_engine.get_finetuned_model()
#      18 else:
#
# File ~/miniconda3/envs/nn/lib/python3.8/site-packages/llama_index/finetuning/embeddings/sentence_transformer.py:79, in SentenceTransformersFinetuneEngine.finetune(self, **train_kwargs)
#      77 def finetune(self, **train_kwargs: Any) -> None:
#      78     """Finetune model."""
# ---> 79     self.model.fit(
#      80         train_objectives=[(self.loader, self.loss)],
#      81         epochs=self.epochs,
#      82         warmup_steps=self.warmup_steps,
#      83         output_path=self.model_output_path,
#      84         show_progress_bar=self.show_progress_bar,
#      85         evaluator=self.evaluator,
#      86         evaluation_steps=self.evaluation_steps,
#      87     )
#
# File ~/miniconda3/envs/nn/lib/python3.8/site-packages/sentence_transformers/fit_mixin.py:356, in FitMixin.fit(self, train_objectives, evaluator, epochs, steps_per_epoch, scheduler, warmup_steps, optimizer_class, optimizer_params, weight_decay, evaluation_steps, output_path, save_best_model, max_grad_norm, use_amp, callback, show_progress_bar, checkpoint_path, checkpoint_save_steps, checkpoint_save_total_limit)
#     353     if callback is not None:
#     354         callbacks.append(OriginalCallback(callback, evaluator))
# --> 356 trainer = SentenceTransformerTrainer(
#     357     model=self,
#     358     args=args,
#     359     train_dataset=train_dataset_dict,
#     360     eval_dataset=None,
#     361     loss=loss_fn_dict,
#     362     evaluator=evaluator,
#     363     optimizers=(optimizer, scheduler_obj),
#     364     callbacks=callbacks,
#     365 )
#     366 # Set the trainer on the EvaluatorCallback, required for logging the metrics
#     367 for callback in trainer.callback_handler.callbacks:
#
# File ~/miniconda3/envs/nn/lib/python3.8/site-packages/sentence_transformers/trainer.py:205, in SentenceTransformerTrainer.__init__(self, model, args, train_dataset, eval_dataset, loss, evaluator, data_collator, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#     203 if isinstance(eval_dataset, dict) and not isinstance(eval_dataset, DatasetDict):
#     204     eval_dataset = DatasetDict(eval_dataset)
# --> 205 super().__init__(
#     206     model=None if self.model_init else model,
#     207     args=args,
#     208     data_collator=data_collator,
#     209     train_dataset=train_dataset,
#     210     eval_dataset=eval_dataset,
#     211     tokenizer=tokenizer,
#     212     model_init=model_init,
#     213     compute_metrics=compute_metrics,
#     214     callbacks=callbacks,
#     215     optimizers=optimizers,
#     216     preprocess_logits_for_metrics=preprocess_logits_for_metrics,
#     217 )
#     218 # Every Sentence Transformer model can always return a loss, so we set this to True
#     219 # to avoid having to specify it in the data collator or model's forward
#     220 self.can_return_loss = True
#
# File ~/miniconda3/envs/nn/lib/python3.8/site-packages/transformers/utils/deprecation.py:165, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     161 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS):
#     162     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     163     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 165 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/nn/lib/python3.8/site-packages/transformers/trainer.py:418, in Trainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, processing_class, model_init, compute_loss_func, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#     412         raise ValueError(
#     413             "When using `batch_eval_metrics`, your `compute_metrics` function must take a `compute_result`"
#     414             " boolean argument which will be triggered after the last batch of the eval set to signal that the"
#     415             " summary statistics should be returned by the function."
#     416         )
#     417 if args.eval_strategy is not None and args.eval_strategy != "no" and eval_dataset is None:
# --> 418     raise ValueError(
#     419         f"You have set `args.eval_strategy` to {args.eval_strategy} but you didn't pass an `eval_dataset` to `Trainer`. Either set `args.eval_strategy` to `no` or pass an `eval_dataset`. "
#     420     )
#     421 self.args = args
#     422 self.compute_loss_func = compute_loss_func
#
# ValueError: You have set `args.eval_strategy` to steps but you didn't pass an `eval_dataset` to `Trainer`. Either set `args.eval_strategy` to `no` or pass an `eval_dataset`.

# %%
## Create a function for evaluation performance of the fine-tuned RAG model.
## This produces many metrics, but we will look at 'cosine_accuracy@3', which
## determines what % of the questions from the validation set, when put through
## RAG retrieval, return the document they were generated from within the top 3.

def evaluate_st(dataset, model_id, name):
    corpus = dataset.corpus
    queries = dataset.queries
    relevant_docs = dataset.relevant_docs

    evaluator = InformationRetrievalEvaluator(queries, corpus, relevant_docs, name=name)
    model = SentenceTransformer(model_id)
    output_path = "results/"
    Path(output_path).mkdir(exist_ok=True, parents=True)
    return evaluator(model, output_path=output_path)

# %%
## First the base model
base_score = evaluate_st(val_dataset, "BAAI/bge-small-en-v1.5", name="bge")['bge_cosine_accuracy@3']
## Next the fine-tuned model
ft_score = evaluate_st(val_dataset, model_ft_path, name="finetuned")['finetuned_cosine_accuracy@3']

print(f'Base model accuracy@3 = {base_score}\nFine-tuned model accuracy@3 = {ft_score}')

# %%
## Now with the updated model, we can re-embed the documents and create
## our fine-tuned RAG system.

output_dir = '../data/bge-small-en-v1.5_openai-tos_vectors-finetuned'

if True:
    ## Generate new vector-index with the fine-tuned embedding model
    index_ft = VectorStoreIndex(
        nodes,
        embed_model = finetuned_embedding_model,
        show_progress=True
    )

    ## Save embeddings with a storage context.
    index_ft.storage_context.persist(persist_dir = output_dir)

else: ## Load vectors
    storage_context = StorageContext.from_defaults(persist_dir = output_dir)
    index_ft = load_index_from_storage(
        storage_context=storage_context,
        embed_model=finetuned_embedding_model
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 10
#       4 output_dir = '../data/bge-small-en-v1.5_openai-tos_vectors-finetuned'
#       6 if True:
#       7     ## Generate new vector-index with the fine-tuned embedding model
#       8     index_ft = VectorStoreIndex(
#       9         nodes,
# ---> 10         embed_model = finetuned_embedding_model,
#      11         show_progress=True
#      12     )
#      14     ## Save embeddings with a storage context.
#      15     index_ft.storage_context.persist(persist_dir = output_dir)
#
# NameError: name 'finetuned_embedding_model' is not defined

# %%
ft_query_engine = index_ft.as_query_engine()

def ft_gpt_and_rag_answers(query,query_engine,llm_engine):
    #gpt_response = OpenAI(model=gpt_model).complete(query)
    llm_response = llm_engine.complete(query)
    rag_response = query_engine.query(query)

    print(f'############\nLLM response:\n{llm_response}\n\n############\nRAG response:\n{rag_response}')
    return llm_response, rag_response

# %%
## Create fine-tuned RAG systems using the original improvements and with
## the re-ranker.

TopK = 5
qa_prompt_tmpl = PromptTemplate(
    "You are an expert Q&A system that is trusted around the world."
    "Always answer the query using the provided context information, and not prior knowledge.\n"
    "Context information is below.\n"
    "---------------------\n"
    "{context_str}\n"
    "---------------------\n"
    "Given the context information and not prior knowledge, answer the query.\n"
    "Query: {query_str}\n"
    "Answer: "
)

###################

retriever_ft = VectorIndexRetriever(
    index=index_ft,
    similarity_top_k=TopK,
)

response_synthesizer_ft = get_response_synthesizer(response_mode=ResponseMode.SIMPLE_SUMMARIZE)

custom_query_engine_ft = RetrieverQueryEngine.from_args(
    retriever_ft,
    response_synthesizer=response_synthesizer_ft,
)
custom_query_engine_ft.update_prompts(
     {"response_synthesizer:text_qa_template": qa_prompt_tmpl}
)

###################

Rerank_TopK = 20
Rerank_TopRRK = 5

retriever_rr_ft = VectorIndexRetriever(
    index=index_ft,
    similarity_top_k=Rerank_TopK,
)

response_synthesizer_rr_ft = get_response_synthesizer(response_mode=ResponseMode.SIMPLE_SUMMARIZE)

custom_query_engine_rerank_ft = RetrieverQueryEngine.from_args(
    retriever_rr_ft,
    response_synthesizer=response_synthesizer_rr_ft,
    node_postprocessors=[
        LLMRerank(
            choice_batch_size=5,
            top_n=Rerank_TopRRK,
        )],
)
custom_query_engine_rerank_ft.update_prompts(
     {"response_synthesizer:text_qa_template": qa_prompt_tmpl}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 20
#       5 qa_prompt_tmpl = PromptTemplate(
#       6     "You are an expert Q&A system that is trusted around the world."
#       7     "Always answer the query using the provided context information, and not prior knowledge.\n"
#    (...)
#      14     "Answer: "
#      15 )
#      17 ###################
#      19 retriever_ft = VectorIndexRetriever(
# ---> 20     index=index_ft,
#      21     similarity_top_k=TopK,
#      22 )
#      24 response_synthesizer_ft = get_response_synthesizer(response_mode=ResponseMode.SIMPLE_SUMMARIZE)
#      26 custom_query_engine_ft = RetrieverQueryEngine.from_args(
#      27     retriever_ft,
#      28     response_synthesizer=response_synthesizer_ft,
#      29 )
#
# NameError: name 'index_ft' is not defined

# %%
query = 'How does ChatGPT deal with inappropriate questions?'

custom_query_engine.query(query).response
# Out:
# "ChatGPT does not allow the building of tools that may be inappropriate for minors, including sexually explicit or suggestive content. Additionally, ChatGPT is required to disclose to people that they are interacting with AI, unless it's obvious from the context."

# %%
custom_query_engine_ft.query(query).response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 custom_query_engine_ft.query(query).response
#
# NameError: name 'custom_query_engine_ft' is not defined

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Context Relevance -- Is the retrieved context relevant to the query?

# %%
## Define a function that wraps the RetrieverEvaluator function from llama_index
def run_context_relevance_eval(index, queries, expected_ids, rerank=False):
    if rerank:
        retriever = VectorIndexRetriever(
            index=index,
            similarity_top_k=20,
            node_postprocessors=[
                LLMRerank(
                    choice_batch_size=5,
                    top_n=2,
                )],
        )
    else:
        retriever = index.as_retriever(similarity_top_k=2)

    retriever_evaluator = RetrieverEvaluator.from_metric_names(
        ["mrr", "hit_rate"], retriever=retriever
    )

    context_eval_results = []
    for cid, q in zip(expected_ids,queries):
        context_relev_eval = retriever_evaluator.evaluate(
            query=q, expected_ids=[cid,]
        )
        context_eval_results.append(context_relev_eval)

    eval_df = pd.DataFrame({
        'query': [cer.query for cer in context_eval_results],
        'expected_ids': [cer.expected_ids for cer in context_eval_results],
        'retrieved_ids': [cer.retrieved_ids for cer in context_eval_results],
        'mrr': [cer.metric_dict['mrr'].score for cer in context_eval_results],
        'hit_rate': [cer.metric_dict['hit_rate'].score for cer in context_eval_results]
    })

    print('Total MRR = ',eval_df.mrr.sum(),'/ ',len(queries))
    print('# Hits = ',eval_df.hit_rate.sum(),'/ ',len(queries))
    return eval_df

## First lets test on our sample Q&A pair
query_id = '0155e8ac-0174-4336-abcc-0ed302230b13'
corpus_id = val_dataset.__dict__['relevant_docs'][query_id][0]
sample_chunk = val_dataset.__dict__['corpus'][corpus_id]
sample_query = val_dataset.__dict__['queries'][query_id]

print('Query:\n', sample_query)
results = run_context_relevance_eval(index,[sample_query,],[corpus_id,])

print('Expected ID = ',results.iloc[0].expected_ids)
print('Retrieved IDs = ',results.iloc[0].retrieved_ids)
print('Top doc:\n',val_dataset.__dict__['corpus'][results.iloc[0].retrieved_ids[0]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 41
#      39 ## First lets test on our sample Q&A pair
#      40 query_id = '0155e8ac-0174-4336-abcc-0ed302230b13'
# ---> 41 corpus_id = val_dataset.__dict__['relevant_docs'][query_id][0]
#      42 sample_chunk = val_dataset.__dict__['corpus'][corpus_id]
#      43 sample_query = val_dataset.__dict__['queries'][query_id]
#
# KeyError: '0155e8ac-0174-4336-abcc-0ed302230b13'

# %%
## Convert the val_dataset Q&A results to a dictionary linking each query
## to the document it was built from
query_ids = list(val_dataset.__dict__['queries'].keys())
corpus_ids = [val_dataset.__dict__['relevant_docs'][qid][0] for qid in query_ids]
queries = [val_dataset.__dict__['queries'][qid] for qid in query_ids]
expected_texts = [val_dataset.__dict__['corpus'][cid] for cid in corpus_ids]
## Create a label mapping from non-finetuned document indexing to fine-tuned doc
## indexing, so we know which document to expect when running the FT model.
index_ids = list(index.__dict__['_index_struct'].nodes_dict.keys())
index_ft_ids = list(index_ft.__dict__['_index_struct'].nodes_dict.keys())
ft_corpus_ids = {index_ids[i]: index_ft_ids[i] for i in range(len(index_ids))}

keys_df = pd.DataFrame({
    'query_ids': query_ids,
    'corpus_ids': corpus_ids,
    'ft_corpus_ids': [ft_corpus_ids[cid] for cid in corpus_ids],
    'queries': queries,
    'expected_texts': expected_texts
}).sample(50,random_state=7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 10
#       7 ## Create a label mapping from non-finetuned document indexing to fine-tuned doc
#       8 ## indexing, so we know which document to expect when running the FT model.
#       9 index_ids = list(index.__dict__['_index_struct'].nodes_dict.keys())
# ---> 10 index_ft_ids = list(index_ft.__dict__['_index_struct'].nodes_dict.keys())
#      11 ft_corpus_ids = {index_ids[i]: index_ft_ids[i] for i in range(len(index_ids))}
#      13 keys_df = pd.DataFrame({
#      14     'query_ids': query_ids,
#      15     'corpus_ids': corpus_ids,
#    (...)
#      18     'expected_texts': expected_texts
#      19 }).sample(50,random_state=7)
#
# NameError: name 'index_ft' is not defined

# %%
results = run_context_relevance_eval(index,keys_df['queries'],keys_df['corpus_ids'],rerank=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 results = run_context_relevance_eval(index,keys_df['queries'],keys_df['corpus_ids'],rerank=True)
#
# NameError: name 'keys_df' is not defined

# %%
results_ft = run_context_relevance_eval(index_ft,keys_df['queries'],keys_df['ft_corpus_ids'],rerank=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 results_ft = run_context_relevance_eval(index_ft,keys_df['queries'],keys_df['ft_corpus_ids'],rerank=True)
#
# NameError: name 'index_ft' is not defined

# %% [markdown]
# ### Answer Relevance -- Is the generated answer relevant to the query?

# %%
## Define a function that wraps the RelevancyEvaluator function from llama_index

def run_answer_relevance_eval(index,queries,rerank=False):

    if rerank:
        query_engine = index.as_query_engine(
            llm=llm_gpt4,
            node_postprocessors=[
                LLMRerank(choice_batch_size=5, top_n=2,
            )],
        )
    else:
        query_engine = index.as_query_engine(llm=llm_gpt4)
    ans_relev_evaluator = RelevancyEvaluator(llm=llm_gpt4)

    answer_eval_results = []
    for query in tqdm(queries):
        response = query_engine.query(query)
        ans_relev_eval = ans_relev_evaluator.evaluate_response(query=query, response=response)
        answer_eval_results.append(ans_relev_eval)

    print(sum([aer.passing for aer in answer_eval_results]))
    return answer_eval_results

query = "How can individuals request corrections for factually inaccurate information about themselves in ChatGPT output?"
results = run_answer_relevance_eval(index,[query,],rerank=True)

print(results[0].response)
print(str(results[0].passing))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
results = run_answer_relevance_eval(index,keys_df['queries'],rerank=True)

# %%
results_ft = run_answer_relevance_eval(index_ft,keys_df['queries'],rerank=True)

# %% [markdown]
# ### Groundedness -- Is the response supported by the context?

# %%
## Define a function that wraps the FaithfulnessEvaluator function from llama_index


def run_groundedness_eval(index,queries,rerank=False):

    if rerank:
        query_engine = index.as_query_engine(
            llm=llm_gpt4,
            node_postprocessors=[
                LLMRerank(choice_batch_size=5, top_n=2,
            )],
        )
    else:
        query_engine = index.as_query_engine(llm=llm_gpt4)
    grnd_eval = FaithfulnessEvaluator(llm=llm_gpt4)

    # responses = [query_engine.query(q) for q in queries]
    # grnd_eval_results = [grnd_eval.evaluate_response(r) for r in responses]
    ground_eval_results = []
    for query in tqdm(queries):
        response = query_engine.query(query)
        ground_eval = faithfulness_eval.evaluate_response(response=response)
        ground_eval_results.append(ground_eval)

    print(sum([ger.passing for ger in ground_eval_results]))
    return ground_eval_results

query = "How can individuals request corrections for factually inaccurate information about themselves in ChatGPT output?"
results = run_answer_relevance_eval(index,[query,],rerank=True)

print('Contexts: ',results[0].contexts)
print('\nResponse: ',results[0].response)
print('\n',str(results[0].passing))

# %%
results = run_groundedness_eval(index,keys_df['queries'],rerank=True)

# %%
results_ft = run_groundedness_eval(index_ft,keys_df['queries'],rerank=True)

# %%
## Create dataframes of the output to example results

grnd_df = pd.DataFrame({
    'query': keys_df['queries'],
    'contexts': [r.contexts for r in results],
    'response': [r.response for r in results],
    'pass': [str(r.passing) for r in results],
    'score': [r.score for r in results]
})

grnd_df_ft = pd.DataFrame({
    'query': keys_df['queries'],
    'contexts': [r.contexts for r in results_ft],
    'response': [r.response for r in results_ft],
    'pass': [str(r.passing) for r in results_ft],
    'score': [r.score for r in results_ft]
})
